# %%
from langchain_tavily import TavilySearch
import os
# Out:
# /Users/rboriba/Developer/langchain-labs/venv/lib/python3.12/site-packages/langchain_tavily/tavily_research.py:97: UserWarning: Field name "output_schema" in "TavilyResearch" shadows an attribute in parent "BaseTool"
#   class TavilyResearch(BaseTool):  # type: ignore[override, override]
# /Users/rboriba/Developer/langchain-labs/venv/lib/python3.12/site-packages/langchain_tavily/tavily_research.py:97: UserWarning: Field name "stream" in "TavilyResearch" shadows an attribute in parent "BaseTool"
#   class TavilyResearch(BaseTool):  # type: ignore[override, override]

# %%
TAVILY_API_KEY = os.getenv("TAVILY_API_KEY")

# %%
tool = TavilySearch()

# %%
response = tool.invoke({"query": "When is ICC Men's T20 World Cup 2024 starting?"})

# %%
response
# Out:
# {'query': "When is ICC Men's T20 World Cup 2024 starting?",
#  'follow_up_questions': None,
#  'answer': None,
#  'images': [],
#  'results': [{'url': 'https://www.imglobal.com/tips/2024-icc-t20-world-cup',
#    'title': "2024 ICC Men's/Women's T20 World Cup",
#    'content': "The 2024 ICC Men's T20 World Cup is scheduled to take place from June 1st to June 29th with 20 teams competing. The events are being co-hosted by the West",
#    'score': 0.9356824,
#    'raw_content': None},
#   {'url': 'https://www.visitlauderdale.com/cricket-world-cup/',
#    'title': "ICC Men's T20 World Cup 2024",
#    'content': 'The matches start in Broward County on Tuesday, June 11 with Sri Lanka vs. Nepal, pick up again on Friday, June 14 with USA vs. Ireland, continue on Saturday,',
#    'score': 0.92794675,
#    'raw_content': None},
#   {'url': 'https://www.youtube.com/watch?v=W3V3dy98KuQ',
#    'title': "ICC Men's T20 World Cup, 2024 Schedule: Date, Venue ...",
#    'content': '... starting from June 1 and the final will be played on June 29. This will be the first ICC World Cup tournament to be held in the United States.',
#    'score': 0.90039873,
#    'raw_content': None},
#   {'url': 'https://www.houstonchronicle.com/news/houston-texas/trending/article/t20-world-cup-cricket-usa-19452575.php',
#    'title': "What to know about Men's Cricket T20 World Cup ...",
#    'content': "The United States and West Indies are hosting the 2024 Men's ICC T20 World Cup from June 1 to June 29.",
#    'score': 0.8877607,
#    'raw_content': None},
#   {'url': 'https://www.icc-cricket.com/news/fixtures-revealed-for-historic-icc-men-s-t20-world-cup-2024-in-west-indies-and-the-usa',
#    'title': "Fixtures revealed for historic ICC Men's T20 World Cup ...",
#    'content': '#### The fixtures for the ninth edition of the ICC Men’s T20 World Cup have been revealed with the event to be co-hosted by the West Indies and the USA from 1 to 29 June 2024. The fixtures for the ninth edition of the ICC Men’s T20 World Cup have been revealed with the event to be co-hosted by the West Indies and the USA from 1 to 29 June 2024. The pinnacle ICC men’s T20 event will see a record 20 teams divided into four groups competing across 55 games for the right to be crowned ICC Men’s T20 World Cup Champions 2024, including co-hosts the West Indies and the USA, together with the other qualifiers: Afghanistan, Australia, Bangladesh, Canada, England, India, Ireland, Namibia, Nepal, the Netherlands, New Zealand, Oman, Pakistan, Papua New Guinea (PNG), Scotland, South Africa, Sri Lanka and Uganda.',
#    'score': 0.8805613,
#    'raw_content': None}],
#  'response_time': 1.29,
#  'request_id': 'b635fef0-19f1-47a1-99d6-d9f362d7e5a6'}

# %%
len (response)
# Out:
# 7

# %%
print(response['results'][0]['url'])
print(response['results'][0]['content'])
# Out:
# https://www.imglobal.com/tips/2024-icc-t20-world-cup
# The 2024 ICC Men's T20 World Cup is scheduled to take place from June 1st to June 29th with 20 teams competing. The events are being co-hosted by the West
