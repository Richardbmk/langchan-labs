# %%
from langchain_core.output_parsers import StrOutputParser
from langchain_core.prompts import ChatPromptTemplate
from langchain_openai import ChatOpenAI
from langchain_core.runnables import RunnablePassthrough

# %%
title = (
    ChatPromptTemplate.from_template(
        "Generate an impactful title for {input}")
    | ChatOpenAI()
    | StrOutputParser()
    | {"title": RunnablePassthrough()}
)

# %%
outline = (
    ChatPromptTemplate.from_template(
        "Generate a detailed outline for {title}"
    )
    | ChatOpenAI()
    | StrOutputParser()
    | {"outline": RunnablePassthrough()}
)

# %%
blog = (
    ChatPromptTemplate.from_template(
        "Generate a 200 word blog post based on the outline: {outline}"
    )
    | ChatOpenAI()
    | StrOutputParser()
    | {"blog": RunnablePassthrough()}
)

# %%
summary = (
    ChatPromptTemplate.from_template(
        "Generate a summary for the post {blog}"
    )
    | ChatOpenAI()
    | StrOutputParser()
)

# %%
content_chain = title | outline | blog | summary

# %%
content_chain.invoke({"input":"The impact of AI on jobs"})
# Out:
# 'Artificial intelligence (AI) is revolutionizing industries by analyzing data, predicting outcomes, and automating tasks. While it enhances efficiency and innovation, it also poses challenges for the job market as automation replaces human tasks. To navigate these changes, individuals must prioritize lifelong learning, collaborate with AI, and plan for career shifts. Government policies are crucial in supporting affected workers. By learning from successful AI integration and adapting individuals, we can anticipate future job trends and opportunities. Embracing change and developing skills will help us thrive in the AI age and shape the future of work.'
