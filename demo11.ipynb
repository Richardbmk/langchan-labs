# %%
from langchain_openai import ChatOpenAI
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.output_parsers import StrOutputParser

# %%
prompt = ChatPromptTemplate.from_template("""
    You are a helpful assistant. 
    Answer the following question: {question}
    """)

# %%
llm = ChatOpenAI()

# %%
output_parser = StrOutputParser()

# %%
chain = prompt | llm | output_parser

# %%
questions=[
    {"question":"Tell me about The Godfather Movie"},
    {"question":"Tell me about Avatar Movie"}
    ]

# %%
response = chain.batch(questions)

# %%
print(response[0])
# Out:
# "The Godfather" is a classic American crime film released in 1972, directed by Francis Ford Coppola and based on the novel by Mario Puzo. The movie follows the Corleone crime family, led by Don Vito Corleone (played by Marlon Brando), as they navigate the world of organized crime in New York City. The film explores themes of power, family, loyalty, and betrayal as the Corleone family faces rival mafia families and internal struggles. The movie is widely considered one of the greatest films of all time, with iconic performances from actors such as Al Pacino, James Caan, and Robert Duvall. "The Godfather" was followed by two sequels, released in 1974 and 1990, which further develop the story of the Corleone family.

# %%
print(response[1])
# Out:
# "Avatar" is a science fiction film directed by James Cameron. It was released in 2009 and is known for its groundbreaking visual effects and 3D technology. The story follows the journey of a paralyzed former marine, Jake Sully, who is sent to the planet Pandora to take part in a mission to collect valuable resources. However, as he becomes more ingrained in the culture and environment of Pandora, he starts to question his allegiances and becomes involved in a struggle between the native Na'vi people and the human corporation mining the planet. The film was a massive success at the box office and received critical acclaim for its storytelling and breathtaking visuals.
