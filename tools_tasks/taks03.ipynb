# %%
from langchain_community.tools.yahoo_finance_news import YahooFinanceNewsTool

# %%
tool = YahooFinanceNewsTool()

# %%
res = tool.run("AAPL")
# Out:
# HTTP Error 404: {"quoteSummary":{"result":null,"error":{"code":"Not Found","description":"Quote not found for symbol: APPLE INC."}}}
# HTTP Error 404: {"quoteSummary":{"result":null,"error":{"code":"Not Found","description":"Quote not found for symbol: APPLE INC."}}}
# No news found for 'Apple Inc.'. Trying broader search...
# HTTP Error 404: {"quoteSummary":{"result":null,"error":{"code":"Not Found","description":"Quote not found for symbol: APPLE INC."}}}
# No news found for 'Apple Inc.'. Trying broader search...
# HTTP Error 404: {"quoteSummary":{"result":null,"error":{"code":"Not Found","description":"Quote not found for symbol: APPLE NEWS"}}}
# HTTP Error 404: {"quoteSummary":{"result":null,"error":{"code":"Not Found","description":"Quote not found for symbol: APPLE INC."}}}
# No news found for 'Apple Inc.'. Trying broader search...
# HTTP Error 404: {"quoteSummary":{"result":null,"error":{"code":"Not Found","description":"Quote not found for symbol: APPLE NEWS"}}}
# No news found for company that searched with Apple news ticker.

# %%
print(res)
# Out:
# No news found for company that searched with AAPL ticker.
