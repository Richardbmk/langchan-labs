# %%
from langchain_openai import ChatOpenAI
from langchain_core.prompts import HumanMessagePromptTemplate 
from langchain_core.prompts import SystemMessagePromptTemplate
from langchain_core.prompts import ChatPromptTemplate 
import os

# %%
sys_msg = "You are a {subject} teacher"
human_msg = "Tell me about {concept}"

# %%
prompt_template = ChatPromptTemplate.from_messages([("system", sys_msg), ("human", human_msg)])

# %%
prompt = prompt_template.format_messages(subject="Chemistry", concept="Periodic Table")

# %%
model = ChatOpenAI()
response = model.invoke(prompt)

# %%
print(response.content)
# Out:
# The Periodic Table is a tabular arrangement of all known chemical elements, organized by their atomic number, electron configuration, and recurring chemical properties. The table was first developed by Russian chemist Dmitri Mendeleev in 1869 and has since undergone many modifications and updates as new elements have been discovered and our understanding of the elements has advanced.
#
# The elements on the Periodic Table are arranged in rows called periods and columns called groups or families. Elements within the same group display similar chemical properties due to their similar electronic configurations. The table also helps predict the chemical behavior of elements based on their position.
#
# The Periodic Table is an essential tool in the study of chemistry as it provides a systematic way to understand the relationships between different elements, their properties, and how they interact with each other.
